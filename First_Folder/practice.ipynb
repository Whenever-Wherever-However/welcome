# %%
from pandas_datareader import data as pdr
import pandas
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

# %%
df = pdr.get_data_yahoo('005930.KS','2017-01-01')
df.info()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1145 entries, 2017-01-02 to 2021-09-09
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1145 non-null   float64
#  1   High       1145 non-null   float64
#  2   Low        1145 non-null   float64
#  3   Close      1145 non-null   float64
#  4   Adj Close  1145 non-null   float64
#  5   Volume     1145 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 62.6 KB

# %%
plt.figure(figsize=(9,6))
plt.subplot(2,1,1)
plt.title('Samsung Electronics (Yahoo Finance)')
plt.plot(df.index, df['Close'],'c',label = 'Close')
plt.plot(df.index, df['Adj Close'], 'b--', label = 'Adj Close')
plt.legend(loc = 'best')
plt.subplot(2,1,2)
plt.bar(df.index, df['Volume'],color = 'g',label = 'Volume')
plt.legend(loc = 'best')

plt.plot(df.index,df['Close'],'c',label = 'Close')
